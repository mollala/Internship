# %% [markdown]
# <a href="https://colab.research.google.com/github/mollala/Internship/blob/DA/%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%99%95%EC%9D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import zipfile
import os

# %%
dframe1 = pd.read_csv('C:/연구인턴십/합친거/tc_codea_코드A.csv')
# filtered_df = dframe1[dframe1['cd_a'] == 'MIS']

# # 필터링된 결과 출력
# print(filtered_df)

dframe1
# Out:
#     idx       cd_nm cd_a                cd_memo  cd_memo2 del_flag  order_num  \
# 0     5        여행상태  STA                    NaN       NaN        N        999
# 1     6     방문지유형코드  VIS                    NaN       NaN        N        999
# 2     7     주요 이동수단  MOV                    NaN       NaN        N        999
# 3     8       재방문여부  REV                    NaN       NaN        N        999
# 4     9      방문선택이유  REN                    NaN       NaN        N        999
# 5    10        숙소유형  HTY                    NaN       NaN        N        999
# 6    11        방문활동  ACT                    NaN       NaN        N        999
# 7    12    취식 지출 여부  EXP                    NaN       NaN        N        999
# 8    13       결제 방식  PAY                    NaN       NaN        N        999
# 9    14  전반적 만족도 점수  DGS                    NaN       NaN        N        999
# 10   15   재방문 의향 점수  REP                    NaN       NaN        N        999
# ...

# %%
dframe2 = pd.read_csv('C:/연구인턴십/합친거/tc_codeb_코드B.csv')

filtered_df = dframe2[dframe2['cd_a'] == 'ACT']

# 필터링된 결과 출력
print(filtered_df)
# Out:
#       idx            cd_nm cd_a cd_b  \
# 63   1055               취식  ACT    1
# 64   1056          쇼핑 / 구매  ACT    2
# 65   1057  체험 활동 / 입장 및 관람  ACT    3
# 66   1058  단순 구경 / 산책 / 걷기  ACT    4
# 67   1059               휴식  ACT    5
# 68   1060            기타 활동  ACT    6
# 102  1094            환승/경유  ACT    7
# 104  1096               없음  ACT   99
#
#                                               cd_memo  cd_memo2 del_flag  \
# 63                                                NaN       NaN        N
# 64    (아이 쇼핑 포함)<br>* 이전 방문지에서 해당 방문지 이동 중 구매한 내역 포함        NaN        N
# 65                                                NaN       NaN        N
# 66                                                NaN       NaN        N
# 67                                                NaN       NaN        N
# 68                                                NaN       NaN        N
# 102                                               NaN       NaN        N
# ...
